# %%
from osgeo import gdal,ogr,osr
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
image_open = gdal.Open(r'F:\wenqu\Aviris\site6\output\ang20170709t004846_corr_v2p9_img_brdf')
# GetDescription provides the path name of the image
image_open.GetDescription()
# Out:
# 'F:\\wenqu\\Aviris\\site6\\output\\ang20170709t004846_corr_v2p9_img_brdf'

# %%
type(image_open.GetMetadata())
# Out:
# dict

# %%
band_dict = image_open.GetMetadata()
dict(sorted(band_dict.items(), key=lambda item: item[1]))
# Out:
# {'Band_126': '1002.94 nanometers',
#  'Band_127': '1007.95 nanometers',
#  'Band_128': '1012.96 nanometers',
#  'Band_129': '1017.97 nanometers',
#  'Band_130': '1022.98 nanometers',
#  'Band_131': '1027.99 nanometers',
#  'Band_132': '1033.0 nanometers',
#  'Band_133': '1038.0 nanometers',
#  'Band_134': '1043.01 nanometers',
#  'Band_135': '1048.02 nanometers',
#  'Band_136': '1053.03 nanometers',
#  'Band_137': '1058.04 nanometers',
#  'Band_138': '1063.05 nanometers',
#  'Band_139': '1068.06 nanometers',
#  'Band_140': '1073.07 nanometers',
#  'Band_141': '1078.07 nanometers',
#  'Band_142': '1083.08 nanometers',
#  'Band_143': '1088.09 nanometers',
#  'Band_144': '1093.1 nanometers',
#  'Band_145': '1098.11 nanometers',
#  'Band_146': '1103.12 nanometers',
#  'Band_147': '1108.13 nanometers',
#  'Band_148': '1113.13 nanometers',
#  'Band_149': '1118.14 nanometers',
#  'Band_150': '1123.15 nanometers',
#  'Band_151': '1128.16 nanometers',
#  'Band_152': '1133.17 nanometers',
# ...
