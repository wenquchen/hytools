# %%
site2a_sla_ymax.shape[0]
# Out:
# 3573

# %%
import numpy as np

# Load the NumPy array from file
site2a_sla_ymax = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\filter_trait\sla_trait_pdf_ymax2.npy',  allow_pickle=True)

for i in range(site2a_sla_ymax.shape[0]):
    print(i,site2a_sla_ymax[i,:] )
# Out:
# 0 [36.958891353044905 'site1b_sla_site1b_10_21.tif']
# 1 [51.853105846986566 'site1b_sla_site1b_10_24.tif']
# 2 [53.43284927819985 'site1b_sla_site1b_10_25.tif']
# 3 [51.55094053588691 'site1b_sla_site1b_10_26.tif']
# 4 [49.310931006262514 'site1b_sla_site1b_10_27.tif']
# 5 [35.657878436666245 'site1b_sla_site1b_10_28.tif']
# 6 [31.808340570196417 'site1b_sla_site1b_10_29.tif']
# 7 [36.12162822181466 'site1b_sla_site1b_10_30.tif']
# 8 [44.79986008105213 'site1b_sla_site1b_10_31.tif']
# 9 [53.08012457863413 'site1b_sla_site1b_10_35.tif']
# 10 [54.080423462342864 'site1b_sla_site1b_10_36.tif']
# 11 [39.08687847466324 'site1b_sla_site1b_11_27.tif']
# 12 [32.78363549539 'site1b_sla_site1b_11_28.tif']
# 13 [44.390879213196044 'site1b_sla_site1b_11_29.tif']
# 14 [54.95132369493982 'site1b_sla_site1b_11_30.tif']
# 15 [39.96583285847274 'site1b_sla_site1b_11_32.tif']
# 16 [60.25603778642352 'site1b_sla_site1b_11_35.tif']
# 17 [53.77249573180587 'site1b_sla_site1b_11_36.tif']
# ...

# %%
threshold = 12
removed_list = [x[1] for x in site2a_la_ymax if x[0] >= threshold]

print(removed_list)
# Out:
# ['site2a_la_site2a_10_24.tif', 'site2a_la_site2a_10_25.tif', 'site2a_la_site2a_10_26.tif', 'site2a_la_site2a_11_24.tif', 'site2a_la_site2a_11_25.tif']

# %%
for i in removed_list:
    print(i)
# Out:
# site2a_la_site2a_10_24.tif
# site2a_la_site2a_10_25.tif
# site2a_la_site2a_10_26.tif
# site2a_la_site2a_11_24.tif
# site2a_la_site2a_11_25.tif

# %%
la_ymax = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\la_trait_pdf_ymax2.npy',  allow_pickle=True)
la_std = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\la_trait_pdf_std2.npy',  allow_pickle=True)

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(la_ymax[:, 1], removed_list)

# Use the mask to filter out the unwanted rows
filtered_laymax_array = la_ymax[~mask]

print(filtered_laymax_array, filtered_laymax_array.shape)
# Out:
# [[7.324553816277909 'site1b_la_site1b_10_21.tif']
#  [11.830876684009086 'site1b_la_site1b_10_24.tif']
#  [10.975914458608152 'site1b_la_site1b_10_25.tif']
#  ...
#  [15.699684545958672 'site6_la_site6_9_47.tif']
#  [14.711243567510083 'site6_la_site6_9_48.tif']
#  [12.373330638213774 'site6_la_site6_9_49.tif']] (3573, 2)

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(la_std[:, 1], removed_list)

# Use the mask to filter out the unwanted rows
filtered_la_std_array = la_std[~mask]

print(filtered_la_std_array, filtered_la_std_array.shape)
# Out:
# [[0.18980145524768152 'site1b_la_site1b_10_21.tif']
#  [0.12074626086740498 'site1b_la_site1b_10_24.tif']
#  [0.12229974237833917 'site1b_la_site1b_10_25.tif']
#  ...
#  [0.039808229505812795 'site6_la_site6_9_47.tif']
#  [0.033926344636437615 'site6_la_site6_9_48.tif']
#  [0.041304743974073126 'site6_la_site6_9_49.tif']] (3573, 2)

# %%
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/la_trait_pdf_ymax2.npy', np.array(filtered_laymax_array, dtype=object), allow_pickle=True)

# %%
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/la_trait_pdf_std2.npy', np.array(filtered_la_std_array, dtype=object), allow_pickle=True)

# %% [markdown]
# # D13C

# %%
D13C_removed_list = []
for i in removed_list:
    new_string = i.replace('la', 'd13c')
    D13C_removed_list.append(new_string)
D13C_removed_list
# Out:
# ['site2a_d13c_site2a_10_24.tif',
#  'site2a_d13c_site2a_10_25.tif',
#  'site2a_d13c_site2a_10_26.tif',
#  'site2a_d13c_site2a_11_24.tif',
#  'site2a_d13c_site2a_11_25.tif']

# %%
d13c_ymax = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\d13c_trait_pdf_ymax2.npy',  allow_pickle=True)
d13c_std = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\d13c_trait_pdf_std2.npy',  allow_pickle=True)

# %%
len(d13c_ymax)
# Out:
# 3578

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(d13c_ymax[:, 1], D13C_removed_list)

# Use the mask to filter out the unwanted rows
filtered_d13c_ymax_array = d13c_ymax[~mask]

print(filtered_d13c_ymax_array, filtered_d13c_ymax_array.shape)
# Out:
# [[6.680403438494835 'site1b_d13c_site1b_10_21.tif']
#  [9.659498027796731 'site1b_d13c_site1b_10_24.tif']
#  [8.600336221097034 'site1b_d13c_site1b_10_25.tif']
#  ...
#  [5.477604581229941 'site6_d13c_site6_9_47.tif']
#  [4.961206713861355 'site6_d13c_site6_9_48.tif']
#  [6.555692440801461 'site6_d13c_site6_9_49.tif']] (3573, 2)

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(d13c_std[:, 1], D13C_removed_list)

# Use the mask to filter out the unwanted rows
filtered_d13c_std_array = d13c_std[~mask]

print(filtered_d13c_std_array, filtered_d13c_std_array.shape)
# Out:
# [[0.21551160407389117 'site1b_d13c_site1b_10_21.tif']
#  [0.142954442273209 'site1b_d13c_site1b_10_24.tif']
#  [0.15608749790485688 'site1b_d13c_site1b_10_25.tif']
#  ...
#  [0.10052253161274351 'site6_d13c_site6_9_47.tif']
#  [0.1173533619864667 'site6_d13c_site6_9_48.tif']
#  [0.09307738511982984 'site6_d13c_site6_9_49.tif']] (3573, 2)

# %%
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/d13c_trait_pdf_ymax2.npy', np.array(filtered_d13c_ymax_array, dtype=object), allow_pickle=True)
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/d13c_trait_pdf_std2.npy', np.array(filtered_d13c_std_array, dtype=object), allow_pickle=True)

# %% [markdown]
# # d15n

# %%
D15n_removed_list = []
for i in removed_list:
    new_string = i.replace('la', 'd15n')
    D15n_removed_list.append(new_string)
D15n_removed_list
# Out:
# ['site2a_d15n_site2a_10_24.tif',
#  'site2a_d15n_site2a_10_25.tif',
#  'site2a_d15n_site2a_10_26.tif',
#  'site2a_d15n_site2a_11_24.tif',
#  'site2a_d15n_site2a_11_25.tif']

# %%
d15n_ymax = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\d15n_trait_pdf_ymax2.npy',  allow_pickle=True)
d15n_std = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\d15n_trait_pdf_std2.npy',  allow_pickle=True)

# %%
len(d15n_ymax)
# Out:
# 3578

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(d15n_ymax[:, 1], D15n_removed_list)

# Use the mask to filter out the unwanted rows
filtered_d15n_ymax_array = d15n_ymax[~mask]

print(filtered_d15n_ymax_array, filtered_d15n_ymax_array.shape)
# Out:
# [[6.185706818397607 'site1b_d15n_site1b_10_21.tif']
#  [10.6358086114019 'site1b_d15n_site1b_10_24.tif']
#  [12.297406205919732 'site1b_d15n_site1b_10_25.tif']
#  ...
#  [2.940533474008577 'site6_d15n_site6_9_47.tif']
#  [3.14681868290243 'site6_d15n_site6_9_48.tif']
#  [3.6480609120011547 'site6_d15n_site6_9_49.tif']] (3573, 2)

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(d15n_std[:, 1], D15n_removed_list)

# Use the mask to filter out the unwanted rows
filtered_d15n_std_array = d15n_std[~mask]

print(filtered_d15n_std_array, filtered_d15n_std_array.shape)
# Out:
# [[0.2378388517323535 'site1b_d15n_site1b_10_21.tif']
#  [0.1452861340431743 'site1b_d15n_site1b_10_24.tif']
#  [0.12270955022099123 'site1b_d15n_site1b_10_25.tif']
#  ...
#  [0.17521057368759477 'site6_d15n_site6_9_47.tif']
#  [0.157222767589954 'site6_d15n_site6_9_48.tif']
#  [0.14871257379809988 'site6_d15n_site6_9_49.tif']] (3573, 2)

# %%
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/d15n_trait_pdf_ymax2.npy', np.array(filtered_d15n_ymax_array, dtype=object), allow_pickle=True)
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/d15n_trait_pdf_std2.npy', np.array(filtered_d15n_std_array, dtype=object), allow_pickle=True)

# %% [markdown]
# # sla

# %%
sla_removed_list = []
for i in removed_list:
    new_string = i.replace('la', 'sla')
    sla_removed_list.append(new_string)
sla_removed_list
# Out:
# ['site2a_sla_site2a_10_24.tif',
#  'site2a_sla_site2a_10_25.tif',
#  'site2a_sla_site2a_10_26.tif',
#  'site2a_sla_site2a_11_24.tif',
#  'site2a_sla_site2a_11_25.tif']

# %%
sla_ymax = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\sla_trait_pdf_ymax2.npy',  allow_pickle=True)
sla_std = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\sla_trait_pdf_std2.npy',  allow_pickle=True)

# %%
len(sla_ymax)
# Out:
# 3578

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(sla_ymax[:, 1], sla_removed_list)

# Use the mask to filter out the unwanted rows
filtered_sla_ymax_array = sla_ymax[~mask]

print(filtered_sla_ymax_array, filtered_sla_ymax_array.shape)
# Out:
# [[36.958891353044905 'site1b_sla_site1b_10_21.tif']
#  [51.853105846986566 'site1b_sla_site1b_10_24.tif']
#  [53.43284927819985 'site1b_sla_site1b_10_25.tif']
#  ...
#  [36.26491390888853 'site6_sla_site6_9_47.tif']
#  [41.567058889607026 'site6_sla_site6_9_48.tif']
#  [35.83955135670861 'site6_sla_site6_9_49.tif']] (3573, 2)

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(sla_std[:, 1], sla_removed_list)

# Use the mask to filter out the unwanted rows
filtered_sla_std_array = sla_std[~mask]

print(filtered_sla_std_array, filtered_sla_std_array.shape)
# Out:
# [[0.03685259428562611 'site1b_sla_site1b_10_21.tif']
#  [0.02655755039343772 'site1b_sla_site1b_10_24.tif']
#  [0.025181249037662896 'site1b_sla_site1b_10_25.tif']
#  ...
#  [0.018799733594607147 'site6_sla_site6_9_47.tif']
#  [0.017544621667286493 'site6_sla_site6_9_48.tif']
#  [0.017845049767409634 'site6_sla_site6_9_49.tif']] (3573, 2)

# %%
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/sla_trait_pdf_ymax2.npy', np.array(filtered_sla_ymax_array, dtype=object), allow_pickle=True)
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/sla_trait_pdf_std2.npy', np.array(filtered_sla_std_array, dtype=object), allow_pickle=True)

# %% [markdown]
# # ldmc

# %%
ldmc_removed_list = []
for i in removed_list:
    new_string = i.replace('la', 'ldmc')
    ldmc_removed_list.append(new_string)
ldmc_removed_list
# Out:
# ['site2a_ldmc_site2a_10_24.tif',
#  'site2a_ldmc_site2a_10_25.tif',
#  'site2a_ldmc_site2a_10_26.tif',
#  'site2a_ldmc_site2a_11_24.tif',
#  'site2a_ldmc_site2a_11_25.tif']

# %%
ldmc_ymax = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\ldmc_trait_pdf_ymax2.npy',  allow_pickle=True)
ldmc_std = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\ldmc_trait_pdf_std2.npy',  allow_pickle=True)

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(ldmc_ymax[:, 1], ldmc_removed_list)

# Use the mask to filter out the unwanted rows
filtered_ldmc_ymax_array = ldmc_ymax[~mask]

print(filtered_ldmc_ymax_array, filtered_ldmc_ymax_array.shape)
# Out:
# [[19.242610256847886 'site1b_ldmc_site1b_10_21.tif']
#  [34.17947646232253 'site1b_ldmc_site1b_10_24.tif']
#  [30.011368102678535 'site1b_ldmc_site1b_10_25.tif']
#  ...
#  [12.345578117057789 'site6_ldmc_site6_9_47.tif']
#  [11.138575440675938 'site6_ldmc_site6_9_48.tif']
#  [13.20200680015094 'site6_ldmc_site6_9_49.tif']] (3573, 2)

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(ldmc_std[:, 1], ldmc_removed_list)

# Use the mask to filter out the unwanted rows
filtered_ldmc_std_array = ldmc_std[~mask]

print(filtered_ldmc_std_array, filtered_ldmc_std_array.shape)
# Out:
# [[0.07207639840080597 'site1b_ldmc_site1b_10_21.tif']
#  [0.04120181084045294 'site1b_ldmc_site1b_10_24.tif']
#  [0.04467208594394953 'site1b_ldmc_site1b_10_25.tif']
#  ...
#  [0.05529510398441666 'site6_ldmc_site6_9_47.tif']
#  [0.050640477645693176 'site6_ldmc_site6_9_48.tif']
#  [0.04891775895479125 'site6_ldmc_site6_9_49.tif']] (3573, 2)

# %%
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/ldmc_trait_pdf_ymax2.npy', np.array(filtered_ldmc_ymax_array, dtype=object), allow_pickle=True)
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/ldmc_trait_pdf_std2.npy', np.array(filtered_ldmc_std_array, dtype=object), allow_pickle=True)

# %% [markdown]
# # pn

# %%
pn_removed_list = []
for i in removed_list:
    new_string = i.replace('la', 'pn')
    pn_removed_list.append(new_string)
pn_removed_list
# Out:
# ['site2a_pn_site2a_10_24.tif',
#  'site2a_pn_site2a_10_25.tif',
#  'site2a_pn_site2a_10_26.tif',
#  'site2a_pn_site2a_11_24.tif',
#  'site2a_pn_site2a_11_25.tif']

# %%
pn_ymax = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\pn_trait_pdf_ymax2.npy',  allow_pickle=True)
pn_std = np.load(r'F:\wenqu\Aviris\Aviris_csv\numpy\pn_trait_pdf_std2.npy',  allow_pickle=True)

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(pn_ymax[:, 1], pn_removed_list)

# Use the mask to filter out the unwanted rows
filtered_pn_ymax_array = pn_ymax[~mask]

print(filtered_pn_ymax_array, filtered_pn_ymax_array.shape)
# Out:
# [[39.463575233090744 'site1b_pn_site1b_10_21.tif']
#  [39.7568333638695 'site1b_pn_site1b_10_24.tif']
#  [49.914797159972984 'site1b_pn_site1b_10_25.tif']
#  ...
#  [22.961197089031423 'site6_pn_site6_9_47.tif']
#  [25.8908930718533 'site6_pn_site6_9_48.tif']
#  [27.12929511771981 'site6_pn_site6_9_49.tif']] (3573, 2)

# %%
# Create a mask of rows to keep (not in items_to_remove)
mask = np.isin(pn_std[:, 1], pn_removed_list)

# Use the mask to filter out the unwanted rows
filtered_pn_std_array = pn_std[~mask]

print(filtered_pn_std_array, filtered_pn_std_array.shape)
# Out:
# [[0.03593809750466064 'site1b_pn_site1b_10_21.tif']
#  [0.034574033538586284 'site1b_pn_site1b_10_24.tif']
#  [0.02703564472989632 'site1b_pn_site1b_10_25.tif']
#  ...
#  [0.03014433394793585 'site6_pn_site6_9_47.tif']
#  [0.026855170613589847 'site6_pn_site6_9_48.tif']
#  [0.028242229109832 'site6_pn_site6_9_49.tif']] (3573, 2)

# %%
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/pn_trait_pdf_ymax2.npy', np.array(filtered_pn_ymax_array, dtype=object), allow_pickle=True)
np.save('F:/wenqu/Aviris/Aviris_csv/numpy/filter_trait/pn_trait_pdf_std2.npy', np.array(filtered_pn_std_array, dtype=object), allow_pickle=True)
