# %%
# import OS module
import os
file_list = []
# Get the list of all files and directories
path = "D:/wenqu/aviris/PLSR/site2a_clip"
dir_list = os.listdir(path)
for file_name in dir_list:
#     print(os.path.splitext(file_name)[0])
    file_list.append(os.path.splitext(file_name)[0])
    
 
# print("Files and directories in '", path, "' :")
 
# prints all files
# print(dir_list)

# %%
file_list.sort()

# %%
len(file_list)
# Out:
# 732

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale 
from sklearn import model_selection
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.cross_decomposition import PLSRegression
from sklearn.metrics import mean_squared_error
from sklearn import model_selection
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from sys import stdout
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from osgeo import gdal,ogr,osr
from scipy.signal import savgol_filter
from scipy.stats import pearsonr
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_error, r2_score

# %%
df_spectral = pd.read_csv(r"D:\wenqu\aviris\PLSR\spectral_statistic.csv")
df_spectral
# Out:
#      row  column    band_1    band_2    band_3    band_4    band_5    band_6  \
# 0     16       0 -0.004657 -0.004544  0.001820  0.003737  0.007674  0.006159
# 1     16       1 -0.003252 -0.004555 -0.002911  0.004232  0.004722  0.006068
# 2     16       2 -0.011871 -0.007262 -0.004665  0.000696  0.002940  0.007108
# 3     16       3 -0.006143 -0.005884 -0.003591  0.000995  0.000714  0.004537
# 4     16       4 -0.008101 -0.005341 -0.002446 -0.001062  0.002247  0.003827
# ..   ...     ...       ...       ...       ...       ...       ...       ...
# 115   19      25 -0.006029 -0.004949 -0.001284  0.002808  0.003133  0.003615
# 116   19      26 -0.010780 -0.009051 -0.006053 -0.003626  0.000123  0.000977
# 117   19      27 -0.001762 -0.002411  0.001318  0.002885  0.005934  0.007781
# 118   19      28 -0.004005 -0.002292  0.001513  0.002730  0.004486  0.005207
# 119   19      29 -0.002324 -0.000857  0.000533  0.001181  0.002846  0.005754
#
# ...

# %%
df_spectral["file_name"] = df_spectral['row'].astype(str) + '_' + df_spectral['column'].astype(int).astype(str)
df_spectral
# Out:
#      row  column    band_1    band_2    band_3    band_4    band_5    band_6  \
# 0     16       0 -0.004657 -0.004544  0.001820  0.003737  0.007674  0.006159
# 1     16       1 -0.003252 -0.004555 -0.002911  0.004232  0.004722  0.006068
# 2     16       2 -0.011871 -0.007262 -0.004665  0.000696  0.002940  0.007108
# 3     16       3 -0.006143 -0.005884 -0.003591  0.000995  0.000714  0.004537
# 4     16       4 -0.008101 -0.005341 -0.002446 -0.001062  0.002247  0.003827
# ..   ...     ...       ...       ...       ...       ...       ...       ...
# 115   19      25 -0.006029 -0.004949 -0.001284  0.002808  0.003133  0.003615
# 116   19      26 -0.010780 -0.009051 -0.006053 -0.003626  0.000123  0.000977
# 117   19      27 -0.001762 -0.002411  0.001318  0.002885  0.005934  0.007781
# 118   19      28 -0.004005 -0.002292  0.001513  0.002730  0.004486  0.005207
# 119   19      29 -0.002324 -0.000857  0.000533  0.001181  0.002846  0.005754
#
# ...

# %%
df_spectral_subset = df_spectral[df_spectral["file_name"].isin(file_list)]
df_spectral_subset
# Out:
#      row  column    band_1    band_2    band_3    band_4    band_5    band_6  \
# 0     16       0 -0.004657 -0.004544  0.001820  0.003737  0.007674  0.006159
# 1     16       1 -0.003252 -0.004555 -0.002911  0.004232  0.004722  0.006068
# 2     16       2 -0.011871 -0.007262 -0.004665  0.000696  0.002940  0.007108
# 3     16       3 -0.006143 -0.005884 -0.003591  0.000995  0.000714  0.004537
# 4     16       4 -0.008101 -0.005341 -0.002446 -0.001062  0.002247  0.003827
# ..   ...     ...       ...       ...       ...       ...       ...       ...
# 115   19      25 -0.006029 -0.004949 -0.001284  0.002808  0.003133  0.003615
# 116   19      26 -0.010780 -0.009051 -0.006053 -0.003626  0.000123  0.000977
# 117   19      27 -0.001762 -0.002411  0.001318  0.002885  0.005934  0.007781
# 118   19      28 -0.004005 -0.002292  0.001513  0.002730  0.004486  0.005207
# 119   19      29 -0.002324 -0.000857  0.000533  0.001181  0.002846  0.005754
#
# ...
