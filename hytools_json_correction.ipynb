# %%
import hytools as ht
import matplotlib.pyplot as plt
import numpy as np

# %%
anc_data = {'path_length': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 0],
 'sensor_az': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 1],
 'sensor_zn': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 2],
 'solar_az': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 3],
 'solar_zn': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 4],
 'phase': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 5],
 'slope': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 6],
 'aspect': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 7],
 'cosine_i': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 8],
 'utc_time': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 9]}

# %%
anc_data
# Out:
# {'path_length': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs',
#   0],
#  'sensor_az': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs',
#   1],
#  'sensor_zn': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs',
#   2],
#  'solar_az': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs',
#   3],
#  'solar_zn': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs',
#   4],
#  'phase': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs',
#   5],
#  'slope': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs',
#   6],
# ...

# %%
envi_image= 'D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319rfl.tar/ang20190704t193319rfl/ang20190704t193319_rfl_v2v2_img'

# anc_data = {'path_length': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 0],
#  'sensor_az': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 1],
#  'sensor_zn': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 2],
#  'solar_az': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 3],
#  'solar_zn': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 4],
#  'phase': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 5],
#  'slope': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 6],
#  'aspect': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 7],
#  'cosine_i': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 8],
#  'utc_time': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 9]}

envi = ht.HyTools()
envi.read_file(envi_image,'envi')

# %%
band = envi.get_band(10)

# %%
band = np.copy(band)
band[~envi.mask['no_data']] = np.nan
plt.matshow(band)

# %%
topo_coeffs = 'D:/wenqu/Aviris/jason/topo_test.json'
envi.load_coeffs(topo_coeffs,'topo')

# brdf_coeffs = 'D:/wenqu/Aviris/jason/topo_test.json'
# envi.load_coeffs(brdf_coeffs,'brdf')

# %%
print(envi.topo)
# Out:
# {'bad_bands': [[300, 400], [1337, 1430], [1800, 1960], [2450, 2600]], 'file_type': 'envi', 'input_files': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319rfl.tar/ang20190704t193319rfl/ang20190704t193319_rfl_v2v2_img'], 'anc_files': {'D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319rfl.tar/ang20190704t193319rfl/ang20190704t193319_rfl_v2v2_img': {'path_length': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 0], 'sensor_az': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 1], 'sensor_zn': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 2], 'solar_az': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang20190704t193319_rdn_v2v2_obs', 3], 'solar_zn': ['D:/wenqu/Aviris/Aviris-NG/2019/ang20190704t193319.tar/ang20190704t193319_rdn_v2v2/ang2019070
# ...

# %%
def show_rgb(hy_obj,r=660,g=550,b=440, correct= []):

    rgb=  np.stack([hy_obj.get_wave(r,corrections= correct),
                    hy_obj.get_wave(g,corrections= correct),
                    hy_obj.get_wave(b,corrections= correct)])
    rgb = np.moveaxis(rgb,0,-1).astype(float)
    rgb[rgb ==hy_obj.no_data] = np.nan

    bottom = np.nanpercentile(rgb,5,axis = (0,1))
    top = np.nanpercentile(rgb,95,axis = (0,1))
    rgb = np.clip(rgb,bottom,top)

    rgb = (rgb-np.nanmin(rgb,axis=(0,1)))/(np.nanmax(rgb,axis= (0,1))-np.nanmin(rgb,axis= (0,1)))

    height = int(hy_obj.lines/hy_obj.columns)

    fig  = plt.figure(figsize = (7,7) )
    plt.imshow(rgb)
    plt.show()
    plt.close()

# %%
show_rgb(envi, correct= [])

# %%
show_rgb(envi, correct = ['topo'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-29077d42c6d6> in <module>
# ----> 1 show_rgb(envi, correct = ['topo'])
#
# <ipython-input-9-f6a5b231fc11> in show_rgb(hy_obj, r, g, b, correct)
#       1 def show_rgb(hy_obj,r=660,g=550,b=440, correct= []):
#       2
# ----> 3     rgb=  np.stack([hy_obj.get_wave(r,corrections= correct),
#       4                     hy_obj.get_wave(g,corrections= correct),
#       5                     hy_obj.get_wave(b,corrections= correct)])
#
# ~\wqc_github\hytools\hytools\base.py in get_wave(self, wave, corrections, mask)
#     244         else:
#     245             band_num = np.argmin(np.abs(self.wavelengths - wave))
# --> 246             band = self.get_band(band_num,corrections= corrections, mask=mask)
#     247         return band
#     248
#
# ...
