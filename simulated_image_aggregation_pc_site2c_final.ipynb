# %%
import numpy as np
# import torch
# from arsf_envi_reader import envi_header
import shutil
import os
import json
import math
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from osgeo import gdal,ogr,osr
from scipy.optimize import curve_fit
# from tqdm import tqdm
# import multiprocess as mp
from scipy import ndimage
from numpy import trapz

# %%
# torch.cuda.is_available()

# %%
high_res_img = gdal.Open(r'D:\wenqu\simulation\site2c\site2c_simulation_update1')
high_res_radiance = gdal.Open(r'D:\wenqu\simulation\site2c\site2c_simulation_update1').ReadAsArray() 

high_res_radiance.shape
# Out:
# (122, 5470, 4744)

# %%
fig = plt.figure(figsize = (10,10))
plt.imshow(high_res_radiance[121,:,:], interpolation='nearest')
plt.show()

# %%
b55= high_res_radiance[53, :, :]
b81_std = ndimage.generic_filter(b55, np.nanstd, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b54_std.npy', b81_std)

# %%
b72 = high_res_radiance[71, :, :]
b72_mean = ndimage.generic_filter(b72, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b72_mean.npy', b72_mean)

# %%
b74 = high_res_radiance[73, :, :]
b74_mean = ndimage.generic_filter(b74, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b74_mean.npy', b74_mean)

b58 = high_res_radiance[57, :, :]
b58_mean = ndimage.generic_filter(b58, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b58_mean.npy', b58_mean)


b29 = high_res_radiance[28, :, :]
b29_mean = ndimage.generic_filter(b29, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b29_mean.npy', b29_mean)

b86 = high_res_radiance[85, :, :]
b86_mean = ndimage.generic_filter(b86, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b86_mean.npy', b86_mean)

b88 = high_res_radiance[87, :, :]
b88_mean = ndimage.generic_filter(b88, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b88_mean.npy', b88_mean)


b36 = high_res_radiance[35, :, :]
b36_mean = ndimage.generic_filter(b36, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b36_mean.npy', b36_mean)


b90= high_res_radiance[89, :, :]
b90_std = ndimage.generic_filter(b90, np.nanstd, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b90_std.npy', b90_std)


b73= high_res_radiance[72, :, :]
b73_std = ndimage.generic_filter(b73, np.nanstd, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b73_std.npy', b73_std)

b97 = high_res_radiance[96, :, :]
b97_mean = ndimage.generic_filter(b97, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b97_mean.npy', b97_mean)


b80 = high_res_radiance[79, :, :]
b80_mean = ndimage.generic_filter(b80, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b80_mean.npy', b80_mean)



b76 = high_res_radiance[75, :, :]
b76_mean = ndimage.generic_filter(b76, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b76_mean.npy', b76_mean)



b82 = high_res_radiance[81, :, :]
b82_mean = ndimage.generic_filter(b82, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b82_mean.npy', b82_mean)

# %%
b94= high_res_radiance[93, :, :]
b94_mean = ndimage.generic_filter(b94, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b94_mean.npy', b94_mean)

b40= high_res_radiance[39, :, :]
b40_mean = ndimage.generic_filter(b40, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b40_mean.npy', b40_mean)


b65= high_res_radiance[64, :, :]
b65_mean = ndimage.generic_filter(b65, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b65_mean.npy', b65_mean)

b93= high_res_radiance[92, :, :]
b93_mean = ndimage.generic_filter(b93, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b93_mean.npy', b93_mean)

b39= high_res_radiance[38, :, :]
b39_mean = ndimage.generic_filter(b39, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b39_mean.npy', b39_mean)

b87= high_res_radiance[86, :, :]
b87_std = ndimage.generic_filter(b87, np.nanstd, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b87_std.npy', b87_std)

b78= high_res_radiance[77, :, :]
b78_mean = ndimage.generic_filter(b78, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b78_mean.npy', b78_mean)

b92= high_res_radiance[91, :, :]
b92_mean = ndimage.generic_filter(b92, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b92_mean.npy', b92_mean)

b95= high_res_radiance[94, :, :]
b95_mean = ndimage.generic_filter(b95, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b95_mean.npy', b95_mean)

b72 = high_res_radiance[71, :, :]
b72_mean = ndimage.generic_filter(b72, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b72_mean.npy', b72_mean)

b74= high_res_radiance[73, :, :]
b74_std = ndimage.generic_filter(b74, np.nanstd, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b74_std.npy', b74_std)

b80= high_res_radiance[79, :, :]
b80_std = ndimage.generic_filter(b80, np.nanstd, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b80_std.npy', b80_std)

b18 = high_res_radiance[17, :, :]
b18_mean = ndimage.generic_filter(b18, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b18_mean.npy', b18_mean)

# %%
b32= high_res_radiance[31, :, :]
b32_mean = ndimage.generic_filter(b32, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b32_mean.npy', b32_mean)


b51 = high_res_radiance[50, :, :]
b51_mean = ndimage.generic_filter(b51, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b51_mean.npy', b51_mean)


b87 = high_res_radiance[86, :, :]
b87_mean = ndimage.generic_filter(b87, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b87_mean.npy', b87_mean)

b42 = high_res_radiance[41, :, :]
b42_mean = ndimage.generic_filter(b42, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b42_mean.npy', b42_mean)

b38 = high_res_radiance[37, :, :]
b38_mean = ndimage.generic_filter(b38, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b38_mean.npy', b38_mean)


b119 = high_res_radiance[118, :, :]
b119_mean = ndimage.generic_filter(b119, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b119_mean.npy', b119_mean)


b76= high_res_radiance[75, :, :]
b76_std = ndimage.generic_filter(b76, np.nanstd, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b76_std.npy', b76_std)

b64 = high_res_radiance[63, :, :]
b64_mean = ndimage.generic_filter(b64, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b64_mean.npy', b64_mean)

# %%
b94= high_res_radiance[93, :, :]
b94_std = ndimage.generic_filter(b94, np.nanstd, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b94_std.npy', b94_std)

# %%
# b77_std
b77= high_res_radiance[76, :, :]
b77_std = ndimage.generic_filter(b77, np.nanstd, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b77_std.npy', b77_std)
# b34_mean
b34= high_res_radiance[33, :, :]
b34_mean = ndimage.generic_filter(b34, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b34_mean.npy', b34_mean)
# b55_std
b55= high_res_radiance[54, :, :]
b55_std = ndimage.generic_filter(b55, np.nanstd, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b55_std.npy', b55_std)

# %%
# b37_mean
b37= high_res_radiance[36, :, :]
b37_mean = ndimage.generic_filter(b37, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b37_mean.npy', b37_mean)

# %%
b116 = high_res_radiance[115, :, :]
b116_mean = ndimage.generic_filter(b116, np.nanmean, size=9, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site2c/b116_mean.npy', b116_mean)

# %%
b23 = high_res_radiance[22, :, :]
b23_std = ndimage.generic_filter(b23, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b23_std.npy', b23_std)

# %%
b26 = high_res_radiance[25, :, :]
b26_std = ndimage.generic_filter(b26, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b26_std.npy', b26_std)

# %%
b109 = high_res_radiance[108, :, :]
b109_std = ndimage.generic_filter(b109, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b109_std.npy', b109_std)

# %%
b5 = high_res_radiance[4, :, :]
b5_mean = ndimage.generic_filter(b5, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b5_mean.npy', b5_mean)

# %%
b1 = high_res_radiance[0, :, :]
b1_mean = ndimage.generic_filter(b1, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b1_mean.npy', b1_mean)

# %%
b26 = high_res_radiance[26, :, :]
b26_mean = ndimage.generic_filter(b26, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b26_mean.npy', b26_mean)

# %%
b27 = high_res_radiance[26, :, :]
b27_mean = ndimage.generic_filter(b27, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b27_mean.npy', b27_mean)

# %%
b106 = high_res_radiance[105, :, :]
b106_std = ndimage.generic_filter(b106, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b106_std.npy', b106_std)

# %%
b40 = high_res_radiance[39, :, :]
b40_std = ndimage.generic_filter(b40, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b40_std.npy', b40_std)

# %%
b7 = high_res_radiance[6, :, :]
b7_mean = ndimage.generic_filter(b7, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b7_mean.npy', b7_mean)

# %%
b5 = high_res_radiance[4, :, :]
b5_std = ndimage.generic_filter(b5, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b5_std.npy', b5_std)

# %%
b12 = high_res_radiance[11, :, :]
b12_std = ndimage.generic_filter(b12, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b12_std.npy', b12_std)

# %%
b4 = high_res_radiance[3, :, :]
b4_mean = ndimage.generic_filter(b4, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b4_mean.npy', b4_mean)

# %%
b3 = high_res_radiance[2, :, :]
b3_mean = ndimage.generic_filter(b3, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b3_mean.npy', b3_mean)

# %%
b118 = high_res_radiance[117, :, :]
b118_std = ndimage.generic_filter(b118, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b118_std.npy', b118_std)

# %%
b9 = high_res_radiance[8, :, :]
b9_mean = ndimage.generic_filter(b9, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b9_mean.npy', b9_mean)

# %%
b115 = high_res_radiance[114, :, :]
b115_std = ndimage.generic_filter(b115, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b115_std.npy', b115_std)

# %%
b32 = high_res_radiance[31, :, :]
b32_std = ndimage.generic_filter(b32, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b32_std.npy', b32_std)

# %%
b8 = high_res_radiance[7, :, :]
b8_mean = ndimage.generic_filter(b8, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b8_mean.npy', b8_mean)

# %%
b16 = high_res_radiance[15, :, :]
b16_mean = ndimage.generic_filter(b16, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b16_mean.npy', b16_mean)

# %%
b28 = high_res_radiance[27, :, :]
b28_std = ndimage.generic_filter(b28, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b28_std.npy', b28_std)

# %%
b103 = high_res_radiance[102, :, :]
b103_std = ndimage.generic_filter(b103, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b103_std.npy', b103_std)

# %%
b8 = high_res_radiance[7, :, :]
b8_std = ndimage.generic_filter(b8, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b8_std.npy', b8_std)

# %%
b4 = high_res_radiance[3, :, :]
b4_std = ndimage.generic_filter(b4, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b4_std.npy', b4_std)

# %%
b21 = high_res_radiance[20, :, :]
b21_std = ndimage.generic_filter(b21, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b21_std.npy', b21_std)

# %%
b14 = high_res_radiance[13, :, :]
b14_std = ndimage.generic_filter(b14, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b14_std.npy', b14_std)

# %%
b120 = high_res_radiance[119, :, :]
b120_mean = ndimage.generic_filter(b120, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b120_mean.npy', b120_mean)

# %%
b55 = high_res_radiance[54, :, :]
b55_mean = ndimage.generic_filter(b55, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b55_mean.npy', b55_mean)

# %%
b106 = high_res_radiance[105, :, :]
b106_mean = ndimage.generic_filter(b106, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b106_mean.npy', b106_mean)

# %%
b29 = high_res_radiance[28, :, :]
b29_std = ndimage.generic_filter(b29, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b29_std.npy', b29_std)

# %%
b24 = high_res_radiance[23, :, :]
b24_mean = ndimage.generic_filter(b24, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b24_mean.npy', b24_mean)

# %%
b25 = high_res_radiance[24, :, :]
b25_mean = ndimage.generic_filter(b25, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b25_mean.npy', b25_mean)

# %%
b60 = high_res_radiance[59, :, :]
b60_std = ndimage.generic_filter(b60, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b60_std.npy', b60_std)

# %%
b37 = high_res_radiance[36, :, :]
b37_std = ndimage.generic_filter(b37, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b37_std.npy', b37_std)

# %%
b59 = high_res_radiance[58, :, :]
b59_std = ndimage.generic_filter(b59, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b59_std.npy', b59_std)

# %%
b30 = high_res_radiance[29, :, :]
b30_std = ndimage.generic_filter(b30, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b30_std.npy', b30_std)

# %%
b14 = high_res_radiance[13, :, :]
b14_mean = ndimage.generic_filter(b14, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b14_mean.npy', b14_mean)

# %%
b10 = high_res_radiance[9, :, :]
b10_std = ndimage.generic_filter(b10, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b10_std.npy', b10_std)

# %%
b31 = high_res_radiance[30, :, :]
b31_std = ndimage.generic_filter(b31, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b31_std.npy', b31_std)

# %%
b57 = high_res_radiance[56, :, :]
b57_mean = ndimage.generic_filter(b57, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b57_mean.npy', b57_mean)

# %%
b108 = high_res_radiance[107, :, :]
b108_mean = ndimage.generic_filter(b108, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b108_mean.npy', b108_mean)

# %%
b116 = high_res_radiance[115, :, :]
b116_std = ndimage.generic_filter(b116, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b116_std.npy', b116_std)

# %%
b41 = high_res_radiance[40, :, :]
b41_mean = ndimage.generic_filter(b41, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b41_mean.npy', b41_mean)

# %%
b20 = high_res_radiance[19, :, :]
b20_std = ndimage.generic_filter(b20, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b20_std.npy', b20_std)

# %%
b56 = high_res_radiance[55, :, :]
b56_mean = ndimage.generic_filter(b56, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b56_mean.npy', b56_mean)

# %%
b110 = high_res_radiance[109, :, :]
b110_std = ndimage.generic_filter(b110, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b110_std.npy', b110_std)

# %%
b30 = high_res_radiance[29, :, :]
b30_mean = ndimage.generic_filter(b30, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b30_mean.npy', b30_mean)

# %%
b45 = high_res_radiance[44, :, :]
b45_std = ndimage.generic_filter(b45, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b45_std.npy', b45_std)

# %%
b47 = high_res_radiance[46, :, :]
b47_mean = ndimage.generic_filter(b47, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b47_mean.npy', b47_mean)

# %%
b43 = high_res_radiance[42, :, :]
b43_std = ndimage.generic_filter(b43, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b43_std.npy', b43_std)

# %%
b69 = high_res_radiance[68, :, :]
b69_mean = ndimage.generic_filter(b69, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b69_mean.npy', b69_mean)

# %%
b3 = high_res_radiance[2, :, :]
b3_std = ndimage.generic_filter(b3, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b3_std.npy', b3_std)

# %%
b69 = high_res_radiance[68, :, :]
b69_std = ndimage.generic_filter(b69, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b69_std.npy', b69_std)

# %%
b99 = high_res_radiance[98, :, :]
b99_std = ndimage.generic_filter(b99, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b99_std.npy', b99_std)

# %%
b67 = high_res_radiance[66, :, :]
b67_mean = ndimage.generic_filter(b67, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b67_mean.npy', b67_mean)

# %%
b50 = high_res_radiance[49, :, :]
b50_mean = ndimage.generic_filter(b50, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b50_mean.npy', b50_mean)

# %%
b28 = high_res_radiance[27, :, :]
b28_mean = ndimage.generic_filter(b28, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b28_mean.npy', b28_mean)

# %%
b67 = high_res_radiance[66, :, :]
b67_std = ndimage.generic_filter(b67, np.nanstd, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b67_std.npy', b67_std)

# %%
b54 = high_res_radiance[53, :, :]
b54_mean = ndimage.generic_filter(b54, np.nanmean, size=9, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site2c/b54_mean.npy', b54_mean)

# %%
site6_logpc_traitmap = (-0.11896496*b119_std 
                        +0.10664171*b107_std
                        -0.086348*b117_std
                        +0.07304101*b108_std
                        -0.07094559*b17_std
                        +0.06625993*b122_mean 
                        -0.06341419*b97_std
                        -0.06157008*b9_std 
                        -0.06129507*b46_std 
                        -0.05904957*b110_mean
                        +0.05886772*b15_std 
                        -0.05829401*b42_std  
                        +0.05618142*b37_std  
                        +0.05422837*b113_std  
                        +0.0535395*b111_std
                        +0.05329481*b86_std  
                        +0.05109891*b6_mean 
                        -0.04969719*b10_mean  
                        +0.04969354*b20_mean  
                        +0.04917988*b114_mean
                        +0.04828722*b113_mean 
                        -0.04732767*b48_mean  
                        +0.04654021*b6_std
                        -0.04487358*b91_std  
                        +0.04483862*b39_std
                        +0.04398*b23_std)

# %%
# site6_logpc_traitmap_array2 = np.asarray(site6_logpc_traitmap)
print(site6_logpc_traitmap.shape)

# %%
pj = high_res_img.GetProjection()  ## projection 
gt = high_res_img.GetGeoTransform()  ## geotransform
col = high_res_img.GetRasterBand(1).XSize
row = high_res_img.GetRasterBand(1).YSize

# %%
driver = gdal.GetDriverByName('GTiff')  ## driver for output file type; "GTiff" for geotiff, "RST" for rst
bands =1
outName = "site1b_logpc_trait_map.tif"
outPath ='D:/wenqu/image_aggregation'
out_ds = driver.Create(os.path.join(outPath, outName),col,row,bands,gdal.GDT_Float32)

# %%
out_ds.GetRasterBand(1).WriteArray(site6_logpc_traitmap)
out_ds.SetProjection(pj)
out_ds.SetGeoTransform(gt)
del out_ds
