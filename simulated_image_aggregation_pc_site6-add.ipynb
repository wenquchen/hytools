# %%
import numpy as np
import torch
# from arsf_envi_reader import envi_header
import shutil
import os
import json
import math
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from osgeo import gdal,ogr,osr
from scipy.optimize import curve_fit
# from tqdm import tqdm
# import multiprocess as mp
from scipy import ndimage
from numpy import trapz

# %%
torch.cuda.is_available()
# Out:
# True

# %%
high_res_img = gdal.Open('E:/wenqu/site6/update/numpy/100173/site6_100173_simulation')
high_res_radiance = gdal.Open('E:/wenqu/site6/update/numpy/100173/site6_100173_simulation').ReadAsArray() 

high_res_radiance.shape
# Out:
# (122, 6836, 6632)

# %%
fig = plt.figure(figsize = (10,10))
plt.imshow(high_res_radiance[121,:,:], interpolation='nearest')
plt.show()

# %%
b120= high_res_radiance[119, :, :]
b120_std = ndimage.generic_filter(b120, np.nanstd, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_100173/b120_std.npy', b120_std)

# %%
b68= high_res_radiance[67, :, :]
b68_std = ndimage.generic_filter(b68, np.nanstd, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_100173/b68_std.npy', b68_std)

# %%
b86= high_res_radiance[85, :, :]
b86_std = ndimage.generic_filter(b86, np.nanstd, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_100173/b86_std.npy', b86_std)

# %%
# Define the filter size
filter_size = 11

# Define the save path
save_path = 'E:/wenqu/numpy_file/npy_file/site6_100173/'
combined_list = ['b111_std', 'b66_std', 'b108_std', 'b39_mean', 
 'b26_mean', 'b60_mean', 'b92_std', 'b48_std', 'b33_mean', 'b98_std', 'b57_mean', 'b80_mean', 'b23_mean', 'b56_mean', 
 'b63_mean', 'b50_mean', 'b10_mean', 'b119_std', 'b36_mean', 'b28_mean', 'b41_mean', 'b73_std', 'b76_std', 'b60_std', 
 'b116_std', 'b43_mean', 'b99_mean', 'b30_std', 'b90_mean', 'b94_std', 'b54_mean', 'b88_std', 'b48_mean', 'b87_mean', 
 'b14_mean', 'b91_std', 'b74_mean', 'b88_mean', 'b7_mean', 'b82_mean', 'b44_std', 'b87_std', 'b53_mean', 'b27_mean', 
 'b38_mean', 'b107_std', 'b112_mean', 'b105_mean', 'b111_mean', 'b12_mean', 'b97_std', 'b42_mean', 'b74_std', 'b76_mean',
 'b99_std', 'b18_mean', 'b34_mean', 'b11_mean', 'b80_std', 
 'b1_std', 'b93_std', 'b119_mean', 'b62_mean', 'b17_mean', 'b115_mean', 'b15_mean', 'b113_mean', 'b89_std']
# Loop through the items in combined_list and calculate/save them
# Loop through the items in combined_list and calculate/save them
for item_name in combined_list:
    # Extract the numeric part of the item name
    index_str = ''.join(filter(str.isdigit, item_name))
    
    # Convert the numeric part to an integer
    idx = int(index_str) - 1
    
    # Calculate and save the item
    data = high_res_radiance[idx, :, :]
    result = ndimage.generic_filter(data, np.nanmean, size=filter_size, mode='constant', cval=np.NaN)
    save_filename = f'{item_name}.npy'
    save_file_path = save_path + save_filename
    np.save(save_file_path, result)

# %%
b74 = high_res_radiance[73, :, :]
b74_mean = ndimage.generic_filter(b74, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b74_mean.npy', b74_mean)

b58 = high_res_radiance[57, :, :]
b58_mean = ndimage.generic_filter(b58, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b58_mean.npy', b58_mean)


b29 = high_res_radiance[28, :, :]
b29_mean = ndimage.generic_filter(b29, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b29_mean.npy', b29_mean)

b86 = high_res_radiance[85, :, :]
b86_mean = ndimage.generic_filter(b86, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b86_mean.npy', b86_mean)

b88 = high_res_radiance[87, :, :]
b88_mean = ndimage.generic_filter(b88, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b88_mean.npy', b88_mean)


b36 = high_res_radiance[35, :, :]
b36_mean = ndimage.generic_filter(b36, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b36_mean.npy', b36_mean)


b90= high_res_radiance[89, :, :]
b90_std = ndimage.generic_filter(b90, np.nanstd, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b90_std.npy', b90_std)


b73= high_res_radiance[72, :, :]
b73_std = ndimage.generic_filter(b73, np.nanstd, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b73_std.npy', b73_std)

b97 = high_res_radiance[96, :, :]
b97_mean = ndimage.generic_filter(b97, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b97_mean.npy', b97_mean)


b80 = high_res_radiance[79, :, :]
b80_mean = ndimage.generic_filter(b80, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b80_mean.npy', b80_mean)



b76 = high_res_radiance[75, :, :]
b76_mean = ndimage.generic_filter(b76, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b76_mean.npy', b76_mean)



b82 = high_res_radiance[81, :, :]
b82_mean = ndimage.generic_filter(b82, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b82_mean.npy', b82_mean)

# %%
b94= high_res_radiance[93, :, :]
b94_mean = ndimage.generic_filter(b94, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b94_mean.npy', b94_mean)

b40= high_res_radiance[39, :, :]
b40_mean = ndimage.generic_filter(b40, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b40_mean.npy', b40_mean)


b65= high_res_radiance[64, :, :]
b65_mean = ndimage.generic_filter(b65, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b65_mean.npy', b65_mean)

b93= high_res_radiance[92, :, :]
b93_mean = ndimage.generic_filter(b93, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b93_mean.npy', b93_mean)

b39= high_res_radiance[38, :, :]
b39_mean = ndimage.generic_filter(b39, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b39_mean.npy', b39_mean)

b87= high_res_radiance[86, :, :]
b87_std = ndimage.generic_filter(b87, np.nanstd, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b87_std.npy', b87_std)

b78= high_res_radiance[77, :, :]
b78_mean = ndimage.generic_filter(b78, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b78_mean.npy', b78_mean)

b92= high_res_radiance[91, :, :]
b92_mean = ndimage.generic_filter(b92, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b92_mean.npy', b92_mean)

b95= high_res_radiance[94, :, :]
b95_mean = ndimage.generic_filter(b95, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b95_mean.npy', b95_mean)

b72 = high_res_radiance[71, :, :]
b72_mean = ndimage.generic_filter(b72, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b72_mean.npy', b72_mean)

b74= high_res_radiance[73, :, :]
b74_std = ndimage.generic_filter(b74, np.nanstd, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b74_std.npy', b74_std)

b80= high_res_radiance[79, :, :]
b80_std = ndimage.generic_filter(b80, np.nanstd, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b80_std.npy', b80_std)

b18 = high_res_radiance[17, :, :]
b18_mean = ndimage.generic_filter(b18, np.nanmean, size=11, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site6_add/b18_mean.npy', b18_mean)

# %%
b116 = high_res_radiance[115, :, :]
b116_std = ndimage.generic_filter(b116, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b116_std.npy', b116_std)

# %%
b41 = high_res_radiance[40, :, :]
b41_mean = ndimage.generic_filter(b41, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b41_mean.npy', b41_mean)

# %%
b20 = high_res_radiance[19, :, :]
b20_std = ndimage.generic_filter(b20, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b20_std.npy', b20_std)

# %%
b56 = high_res_radiance[55, :, :]
b56_mean = ndimage.generic_filter(b56, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b56_mean.npy', b56_mean)

# %%
b110 = high_res_radiance[109, :, :]
b110_std = ndimage.generic_filter(b110, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b110_std.npy', b110_std)

# %%
b30 = high_res_radiance[29, :, :]
b30_mean = ndimage.generic_filter(b30, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b30_mean.npy', b30_mean)

# %%
b45 = high_res_radiance[44, :, :]
b45_std = ndimage.generic_filter(b45, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b45_std.npy', b45_std)

# %%
b47 = high_res_radiance[46, :, :]
b47_mean = ndimage.generic_filter(b47, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b47_mean.npy', b47_mean)

# %%
b43 = high_res_radiance[42, :, :]
b43_std = ndimage.generic_filter(b43, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b43_std.npy', b43_std)

# %%
b69 = high_res_radiance[68, :, :]
b69_mean = ndimage.generic_filter(b69, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b69_mean.npy', b69_mean)

# %%
b3 = high_res_radiance[2, :, :]
b3_std = ndimage.generic_filter(b3, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b3_std.npy', b3_std)

# %%
b69 = high_res_radiance[68, :, :]
b69_std = ndimage.generic_filter(b69, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b69_std.npy', b69_std)

# %%
b99 = high_res_radiance[98, :, :]
b99_std = ndimage.generic_filter(b99, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b99_std.npy', b99_std)

# %%
b67 = high_res_radiance[66, :, :]
b67_mean = ndimage.generic_filter(b67, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b67_mean.npy', b67_mean)

# %%
b50 = high_res_radiance[49, :, :]
b50_mean = ndimage.generic_filter(b50, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b50_mean.npy', b50_mean)

# %%
b28 = high_res_radiance[27, :, :]
b28_mean = ndimage.generic_filter(b28, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b28_mean.npy', b28_mean)

# %%
b67 = high_res_radiance[66, :, :]
b67_std = ndimage.generic_filter(b67, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b67_std.npy', b67_std)

# %%
b54 = high_res_radiance[53, :, :]
b54_mean = ndimage.generic_filter(b54, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b54_mean.npy', b54_mean)

# %%
b121 = high_res_radiance[120, :, :]
b121_std = ndimage.generic_filter(b121, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b121_std.npy', b121_std)

# %%
b109 = high_res_radiance[108, :, :]
b109_std = ndimage.generic_filter(b109, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b109_std.npy', b109_std)

# %%
b14 = high_res_radiance[13, :, :]
b14_std = ndimage.generic_filter(b14, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b14_std.npy', b14_std)

# %%
b9 = high_res_radiance[8, :, :]
b9_mean = ndimage.generic_filter(b9, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b9_mean.npy', b9_mean)

# %%
b53= high_res_radiance[52, :, :]
b53_std = ndimage.generic_filter(b53, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b53_std.npy', b53_std)

# %%
b89= high_res_radiance[88, :, :]
b89_std = ndimage.generic_filter(b89, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b89_std.npy', b89_std)

# %%
b117 = high_res_radiance[116, :, :]
b117_mean = ndimage.generic_filter(b117, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b117_mean.npy', b117_mean)

# %%
b93 = high_res_radiance[92, :, :]
b93_std = ndimage.generic_filter(b93, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b93_std.npy', b93_std)

# %%
b16 = high_res_radiance[15, :, :]
b16_std = ndimage.generic_filter(b16, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b16_std.npy', b16_std)

# %%
b96 = high_res_radiance[95, :, :]
b96_std = ndimage.generic_filter(b96, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b96_std.npy', b96_std)

# %%
b35 = high_res_radiance[34, :, :]
b35_std = ndimage.generic_filter(b35, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b35_std.npy', b35_std)

# %%
b41 = high_res_radiance[40, :, :]
b41_std = ndimage.generic_filter(b41, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b41_std.npy', b41_std)

# %%
b19 = high_res_radiance[18, :, :]
b19_mean = ndimage.generic_filter(b19, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b19_mean.npy', b19_mean)

# %%
b98 = high_res_radiance[97, :, :]
b98_std = ndimage.generic_filter(b98, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b98_std.npy', b98_std)

# %%
b33 = high_res_radiance[32, :, :]
b33_std = ndimage.generic_filter(b33, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b33_std.npy', b33_std)

# %%
b105 = high_res_radiance[104, :, :]
b105_std = ndimage.generic_filter(b105, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b105_std.npy', b105_std)

# %%
b85 = high_res_radiance[84, :, :]
b85_std = ndimage.generic_filter(b85, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b85_std.npy', b85_std)

# %%
b75 = high_res_radiance[74, :, :]
b75_std = ndimage.generic_filter(b75, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b75_std.npy', b75_std)

# %%
b21 = high_res_radiance[20, :, :]
b21_std = ndimage.generic_filter(b21, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b21_std.npy', b21_std)

# %%
b101 = high_res_radiance[100, :, :]
b101_mean = ndimage.generic_filter(b101, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b101_mean.npy', b101_mean)

# %%
b25 = high_res_radiance[24, :, :]
b25_std = ndimage.generic_filter(b25, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b25_std.npy', b25_std)

# %%
b49 = high_res_radiance[48, :, :]
b49_mean = ndimage.generic_filter(b49, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b49_mean.npy', b49_mean)

# %%
b68 = high_res_radiance[67, :, :]
b68_mean = ndimage.generic_filter(b68, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b68_mean.npy', b68_mean)

# %%
b84 = high_res_radiance[83, :, :]
b84_std = ndimage.generic_filter(b84, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b84_std.npy', b84_std)

# %%
b104 = high_res_radiance[103, :, :]
b104_mean = ndimage.generic_filter(b104, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b104_mean.npy', b104_mean)

# %%
b46 = high_res_radiance[45, :, :]
b46_mean = ndimage.generic_filter(b46, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b46_mean.npy', b46_mean)

# %%
b25 = high_res_radiance[24, :, :]
b25_mean = ndimage.generic_filter(b25, np.nanmean, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b25_mean.npy', b25_mean)

# %%
b106 = high_res_radiance[105, :, :]
b106_std = ndimage.generic_filter(b106, np.nanstd, size=11, mode='constant', cval=np.NaN)

np.save('E:/wenqu/numpy_file/npy_file/site6_add/b106_std.npy', b106_std)
