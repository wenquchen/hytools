# %%
import numpy as np
import torch
# from arsf_envi_reader import envi_header
import shutil
import os
import json
import math
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from osgeo import gdal,ogr,osr
from scipy.optimize import curve_fit
# from tqdm import tqdm
# import multiprocess as mp
from scipy import ndimage
from numpy import trapz

# %%
torch.cuda.is_available()
# Out:
# True

# %%
high_res_img = gdal.Open(r'E:\wenqu\copy\site1b_simulation_mosaic')
high_res_radiance = gdal.Open(r'E:\wenqu\copy\site1b_simulation_mosaic').ReadAsArray() 

high_res_radiance.shape
# Out:
# (122, 19347, 10637)

# %%
fig = plt.figure(figsize = (10,10))
plt.imshow(high_res_radiance[121,:,:], interpolation='nearest')
plt.show()

# %%
# b117 = high_res_radiance[116, :, :]
# b117_mean = ndimage.generic_filter(b117, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b117_mean.npy', b117_mean)





# b11 = high_res_radiance[10, :, :]
# b11_mean = ndimage.generic_filter(b11, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b11_mean.npy', b11_mean)


# # 'b115_std', 
# b115 = high_res_radiance[114, :, :]
# b115_std = ndimage.generic_filter(b115, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b115_std.npy', b115_std)



# # 'b3_std', 

# b3 = high_res_radiance[2, :, :]
# b3_std = ndimage.generic_filter(b3, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b3_std.npy', b3_std)


# # 'b54_mean',

# b54 = high_res_radiance[53, :, :]
# b54_mean = ndimage.generic_filter(b54, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b54_mean.npy', b54_mean)

# # 'b120_mean',
# b120 = high_res_radiance[119, :, :]
# b120_mean = ndimage.generic_filter(b120, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b120_mean.npy', b120_mean)

# # 'b28_std',

# b28 = high_res_radiance[27, :, :]
# b28_std = ndimage.generic_filter(b28, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b28_std.npy', b28_std)


# # 'b27_mean', 
# b27 = high_res_radiance[26, :, :]
# b27_mean = ndimage.generic_filter(b27, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b27_mean.npy', b27_mean)

# # 'b14_std',
# b14 = high_res_radiance[13, :, :]
# b14_std = ndimage.generic_filter(b14, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b14_std.npy', b14_std)
# # 'b109_mean',
# b109 = high_res_radiance[108, :, :]
# b109_mean = ndimage.generic_filter(b109, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b109_mean.npy', b109_mean)
# # 'b6_std',
# b6 = high_res_radiance[5, :, :]
# b6_std = ndimage.generic_filter(b6, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b6_std.npy', b6_std)

# # 'b59_std', 
# b59 = high_res_radiance[58, :, :]
# b59_std = ndimage.generic_filter(b59, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b59_std.npy', b59_std)

# # 'b106_mean',
# b106 = high_res_radiance[105, :, :]
# b106_mean = ndimage.generic_filter(b106, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b106_mean.npy', b106_mean)


# # 'b50_mean', 
# b50 = high_res_radiance[49, :, :]
# b50_mean = ndimage.generic_filter(b50, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b50_mean.npy', b50_mean)

# # 'b69_std', 
# b69 = high_res_radiance[68, :, :]
# b69_std = ndimage.generic_filter(b69, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b69_std.npy', b69_std)

# # 'b122_std', 
# b122 = high_res_radiance[121, :, :]
# b122_std = ndimage.generic_filter(b122, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b122_std.npy', b122_std)

# # 'b4_mean', 
# b4 = high_res_radiance[3, :, :]
# b4_mean = ndimage.generic_filter(b4, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b4_mean.npy', b4_mean)

# # 'b101_mean',
# b101 = high_res_radiance[100, :, :]
# b101_mean = ndimage.generic_filter(b101, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b101_mean.npy', b101_mean)
# # 'b30_mean',
# b30 = high_res_radiance[29, :, :]
# b30_mean = ndimage.generic_filter(b30, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b30_mean.npy', b30_mean)

# # 'b4_std',
# b4 = high_res_radiance[3, :, :]
# b4_std = ndimage.generic_filter(b4, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b4_std.npy', b4_std)

# # 'b116_std',
# b116 = high_res_radiance[115, :, :]
# b116_std = ndimage.generic_filter(b116, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b116_std.npy', b116_std)

# # 'b105_mean',
# b105 = high_res_radiance[104, :, :]
# b105_mean = ndimage.generic_filter(b105, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b105_mean.npy', b105_mean)


# # 'b56_mean', 
# b56 = high_res_radiance[55, :, :]
# b56_mean = ndimage.generic_filter(b56, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b56_mean.npy', b56_mean)

# # 'b99_std', 
# b99 = high_res_radiance[98, :, :]
# b99_std = ndimage.generic_filter(b99, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b99_std.npy', b99_std)

# # 'b122_mean',
# b122 = high_res_radiance[121, :, :]
# b122_mean = ndimage.generic_filter(b122, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b122_mean.npy', b122_mean)

# # 'b68_mean', 
# b68 = high_res_radiance[68, :, :]
# b68_mean = ndimage.generic_filter(b68, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b68_mean.npy', b68_mean)

# # 'b91_std', 
# b91 = high_res_radiance[90, :, :]
# b91_std = ndimage.generic_filter(b91, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b91_std.npy', b91_std)

# # 'b103_std',
# b103 = high_res_radiance[102, :, :]
# b103_std = ndimage.generic_filter(b103, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b103_std.npy', b103_std)

# # 'b21_std',
# b21 = high_res_radiance[20, :, :]
# b21_std = ndimage.generic_filter(b21, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b21_std.npy', b21_std)

# # 'b62_mean',
# b62 = high_res_radiance[61, :, :]
# b62_mean = ndimage.generic_filter(b62, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b62_mean.npy', b62_mean)

# # 'b43_std',
# b43 = high_res_radiance[42, :, :]
# b43_std = ndimage.generic_filter(b43, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b43_std.npy', b43_std)


# # 'b11_std', 
# b11 = high_res_radiance[10, :, :]
# b11_std = ndimage.generic_filter(b11, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('D:/wenqu/simulation/npy_file/site1b/b11_std.npy', b11_std)

# 'b47_std', 
# b47 = high_res_radiance[46, :, :]
# b47_std = ndimage.generic_filter(b47, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/site1b/b47_std.npy', b47_std)

# # 'b55_mean',
# b55 = high_res_radiance[54, :, :]
# b55_mean = ndimage.generic_filter(b55, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/site1b/b55_mean.npy', b55_mean)

# # 'b110_std', 
# b110 = high_res_radiance[109, :, :]
# b110_std = ndimage.generic_filter(b110, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/site1b/b110_std.npy', b110_std)

# # 'b26_mean',
# b26 = high_res_radiance[25, :, :]
# b26_mean = ndimage.generic_filter(b26, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/site1b/b26_mean.npy', b26_mean)

# # 'b41_mean', 
# b41 = high_res_radiance[40, :, :]
# b41_mean = ndimage.generic_filter(b41, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/site1b/b41_mean.npy', b41_mean)

# 'b93_std',
b93 = high_res_radiance[92, :, :]
b93_std = ndimage.generic_filter(b93, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b93_std.npy', b93_std)

# 'b63_std', 
b63 = high_res_radiance[62, :, :]
b63_std = ndimage.generic_filter(b63, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b63_std.npy', b63_std)

# 'b68_std', 
b68 = high_res_radiance[67, :, :]
b68_std = ndimage.generic_filter(b68, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b68_std.npy', b68_std)

# 'b105_std', 
b105 = high_res_radiance[104, :, :]
b105_std = ndimage.generic_filter(b105, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b105_std.npy', b105_std)


# 'b96_std', 
# 'b89_std', 
# 'b49_mean',
# 'b110_mean',
# 'b5_std',
# 'b67_mean',
# 'b10_std',
# 'b53_std',
# 'b19_std', 
# 'b57_mean',
# 'b35_std', 
# 'b104_std',
# 'b69_mean', 

# 'b123_mean',
# 'b24_std', 
# 'b118_std',
# 'b26_std', 
# 'b7_mean',
# 'b33_std',
# 'b16_std', 
# 'b1_std', 
# 'b41_std', 
# 'b75_std',
# 'b103_mean',
# 'b28_mean',
# 'b3_mean'

# %%
b13 = high_res_radiance[12, :, :]
b13_std = ndimage.generic_filter(b13, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b13_std.npy', b13_std)

b7 = high_res_radiance[6, :, :]
b7_std = ndimage.generic_filter(b7, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b7_std.npy', b7_std)

b61 = high_res_radiance[60, :, :]
b61_std = ndimage.generic_filter(b61, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b61_std.npy', b61_std)

b33 = high_res_radiance[32, :, :]
b33_mean = ndimage.generic_filter(b33, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('D:/wenqu/simulation/npy_file/site1b/b33_mean.npy', b33_mean)

b34 = high_res_radiance[33, :, :]
b34_std = ndimage.generic_filter(b34, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b34_std.npy', b34_std)

b99 = high_res_radiance[98, :, :]
b99_mean = ndimage.generic_filter(b99, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('D:/wenqu/simulation/npy_file/site1b/b99_mean.npy', b99_mean)

b79 = high_res_radiance[78, :, :]
b79_std = ndimage.generic_filter(b79, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b79_std.npy', b79_std)


b31 = high_res_radiance[30, :, :]
b31_mean = ndimage.generic_filter(b31, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('D:/wenqu/simulation/npy_file/site1b/b31_mean.npy', b31_mean)

b43 = high_res_radiance[42, :, :]
b43_mean = ndimage.generic_filter(b43, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('D:/wenqu/simulation/npy_file/site1b/b43_mean.npy', b43_mean)

b115 = high_res_radiance[114, :, :]
b115_mean = ndimage.generic_filter(b115, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('D:/wenqu/simulation/npy_file/site1b/b115_mean.npy', b115_mean)

b56 = high_res_radiance[55, :, :]
b56_std = ndimage.generic_filter(b56, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b56_std.npy', b56_std)

b112 = high_res_radiance[111, :, :]
b112_std = ndimage.generic_filter(b112, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b112_std.npy', b112_std)

b15 = high_res_radiance[14, :, :]
b15_mean = ndimage.generic_filter(b15, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('D:/wenqu/simulation/npy_file/site1b/b15_mean.npy', b15_mean)

b70 = high_res_radiance[69, :, :]
b70_mean = ndimage.generic_filter(b70, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('D:/wenqu/simulation/npy_file/site1b/b70_mean.npy', b70_mean)

b101 = high_res_radiance[100, :, :]
b101_std = ndimage.generic_filter(b101, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b101_std.npy', b101_std)


b66 = high_res_radiance[65, :, :]
b66_mean = ndimage.generic_filter(b66, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('D:/wenqu/simulation/npy_file/site1b/b66_mean.npy', b66_mean)

# %%
# 'b96_std', 
b96 = high_res_radiance[95, :, :]
b96_std = ndimage.generic_filter(b96, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b96_std.npy', b96_std)
# 'b89_std', 
b89 = high_res_radiance[89, :, :]
b89_std = ndimage.generic_filter(b89, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b89_std.npy', b89_std)
# 'b49_mean',
b49 = high_res_radiance[48, :, :]
b49_mean = ndimage.generic_filter(b49, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b49_mean.npy', b49_mean)
# 'b110_mean',
b110 = high_res_radiance[109, :, :]
b110_mean = ndimage.generic_filter(b110, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b110_mean.npy', b110_mean)
# 'b5_std',
b5 = high_res_radiance[4, :, :]
b5_std = ndimage.generic_filter(b5, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b5_std.npy', b5_std)
# 'b67_mean',
b67 = high_res_radiance[66, :, :]
b67_mean = ndimage.generic_filter(b67, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b67_mean.npy', b67_mean)
# 'b10_std',
b10 = high_res_radiance[9, :, :]
b10_std = ndimage.generic_filter(b10, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b10_std.npy', b10_std)
# 'b53_std',
b53 = high_res_radiance[52, :, :]
b53_std = ndimage.generic_filter(b53, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b53_std.npy', b53_std)
# 'b19_std', 
b19 = high_res_radiance[18, :, :]
b19_std = ndimage.generic_filter(b19, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b19_std.npy', b19_std)
# 'b57_mean',
b57 = high_res_radiance[56, :, :]
b57_std = ndimage.generic_filter(b57, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b57_std.npy', b57_std)
# 'b35_std', 
b35 = high_res_radiance[34, :, :]
b35_std = ndimage.generic_filter(b35, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/site1b/b35_std.npy', b35_std)

# %%
b121 = high_res_radiance[120, :, :]
b121_std = ndimage.generic_filter(b121, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b121_std.npy', b121_std)

# %%
b109 = high_res_radiance[108, :, :]
b109_std = ndimage.generic_filter(b109, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b109_std.npy', b109_std)

# %%
b14 = high_res_radiance[13, :, :]
b14_std = ndimage.generic_filter(b14, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b14_std.npy', b14_std)

# %%
b9 = high_res_radiance[8, :, :]
b9_mean = ndimage.generic_filter(b9, np.nanmean, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b9_mean.npy', b9_mean)

# %%
b53= high_res_radiance[52, :, :]
b53_std = ndimage.generic_filter(b53, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b53_std.npy', b53_std)

# %%
b89= high_res_radiance[88, :, :]
b89_std = ndimage.generic_filter(b89, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b89_std.npy', b89_std)

# %%
b117 = high_res_radiance[116, :, :]
b117_mean = ndimage.generic_filter(b117, np.nanmean, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b117_mean.npy', b117_mean)

# %%
b93 = high_res_radiance[92, :, :]
b93_std = ndimage.generic_filter(b93, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b93_std.npy', b93_std)

# %%
b16 = high_res_radiance[15, :, :]
b16_std = ndimage.generic_filter(b16, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b16_std.npy', b16_std)

# %%
b96 = high_res_radiance[95, :, :]
b96_std = ndimage.generic_filter(b96, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b96_std.npy', b96_std)

# %%
b35 = high_res_radiance[34, :, :]
b35_std = ndimage.generic_filter(b35, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b35_std.npy', b35_std)

# %%
b41 = high_res_radiance[40, :, :]
b41_std = ndimage.generic_filter(b41, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b41_std.npy', b41_std)

# %%
b19 = high_res_radiance[18, :, :]
b19_mean = ndimage.generic_filter(b19, np.nanmean, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b19_mean.npy', b19_mean)

# %%
b98 = high_res_radiance[97, :, :]
b98_std = ndimage.generic_filter(b98, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b98_std.npy', b98_std)

# %%
b33 = high_res_radiance[32, :, :]
b33_std = ndimage.generic_filter(b33, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b33_std.npy', b33_std)

# %%
b105 = high_res_radiance[104, :, :]
b105_std = ndimage.generic_filter(b105, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b105_std.npy', b105_std)

# %%
b85 = high_res_radiance[84, :, :]
b85_std = ndimage.generic_filter(b85, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b85_std.npy', b85_std)

# %%
b75 = high_res_radiance[74, :, :]
b75_std = ndimage.generic_filter(b75, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b75_std.npy', b75_std)

# %%
b21 = high_res_radiance[20, :, :]
b21_std = ndimage.generic_filter(b21, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b21_std.npy', b21_std)

# %%
b101 = high_res_radiance[100, :, :]
b101_mean = ndimage.generic_filter(b101, np.nanmean, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b101_mean.npy', b101_mean)

# %%
b25 = high_res_radiance[24, :, :]
b25_std = ndimage.generic_filter(b25, np.nanstd, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b25_std.npy', b25_std)

# %%
b49 = high_res_radiance[48, :, :]
b49_mean = ndimage.generic_filter(b49, np.nanmean, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b49_mean.npy', b49_mean)

# %%
b68 = high_res_radiance[67, :, :]
b68_mean = ndimage.generic_filter(b68, np.nanmean, size=19, mode='constant', cval=np.NaN)

np.save('D:/wenqu/simulation/npy_file/site1b/b68_mean.npy', b68_mean)

# %%
site6_logpc_traitmap = (-0.11896496*b119_std 
                        +0.10664171*b107_std
                        -0.086348*b117_std
                        +0.07304101*b108_std
                        -0.07094559*b17_std
                        +0.06625993*b122_mean 
                        -0.06341419*b97_std
                        -0.06157008*b9_std 
                        -0.06129507*b46_std 
                        -0.05904957*b110_mean
                        +0.05886772*b15_std 
                        -0.05829401*b42_std  
                        +0.05618142*b37_std  
                        +0.05422837*b113_std  
                        +0.0535395*b111_std
                        +0.05329481*b86_std  
                        +0.05109891*b6_mean 
                        -0.04969719*b10_mean  
                        +0.04969354*b20_mean  
                        +0.04917988*b114_mean
                        +0.04828722*b113_mean 
                        -0.04732767*b48_mean  
                        +0.04654021*b6_std
                        -0.04487358*b91_std  
                        +0.04483862*b39_std
                        +0.04398*b23_std)

# %%
# site6_logpc_traitmap_array2 = np.asarray(site6_logpc_traitmap)
print(site6_logpc_traitmap.shape)

# %%
pj = high_res_img.GetProjection()  ## projection 
gt = high_res_img.GetGeoTransform()  ## geotransform
col = high_res_img.GetRasterBand(1).XSize
row = high_res_img.GetRasterBand(1).YSize

# %%
driver = gdal.GetDriverByName('GTiff')  ## driver for output file type; "GTiff" for geotiff, "RST" for rst
bands =1
outName = "site1b_logpc_trait_map.tif"
outPath ='D:/wenqu/image_aggregation'
out_ds = driver.Create(os.path.join(outPath, outName),col,row,bands,gdal.GDT_Float32)

# %%
out_ds.GetRasterBand(1).WriteArray(site6_logpc_traitmap)
out_ds.SetProjection(pj)
out_ds.SetGeoTransform(gt)
del out_ds
