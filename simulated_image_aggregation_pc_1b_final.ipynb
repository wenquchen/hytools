# %%
import numpy as np
# import torch
# from arsf_envi_reader import envi_header
import shutil
import os
import json
import math
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from osgeo import gdal,ogr,osr
from scipy.optimize import curve_fit
# from tqdm import tqdm
# import multiprocess as mp
from scipy import ndimage
from numpy import trapz

# %%
# torch.cuda.is_available()

# %%
high_res_img = gdal.Open(r'D:\wenqu\mosaic\site1b\copy\site1b_simulation_mosaic')
high_res_radiance = gdal.Open(r'D:\wenqu\mosaic\site1b\copy\site1b_simulation_mosaic').ReadAsArray() 

high_res_radiance.shape
# Out:
# (122, 19347, 10637)

# %%
fig = plt.figure(figsize = (10,10))
plt.imshow(high_res_radiance[121,:,:], interpolation='nearest')
plt.show()

# %%
b85_mean
b35_mean

# %%
b55= high_res_radiance[53, :, :]
b55_std = ndimage.generic_filter(b55, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b54_std.npy', b55_std)

# %%
# b94= high_res_radiance[93, :, :]
# b94_mean = ndimage.generic_filter(b94, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b94_mean.npy', b94_mean)

# b40= high_res_radiance[39, :, :]
# b40_mean = ndimage.generic_filter(b40, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b40_mean.npy', b40_mean)


# b65= high_res_radiance[64, :, :]
# b65_mean = ndimage.generic_filter(b65, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b65_mean.npy', b65_mean)

# b93= high_res_radiance[92, :, :]
# b93_mean = ndimage.generic_filter(b93, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b93_mean.npy', b93_mean)

# b39= high_res_radiance[38, :, :]
# b39_mean = ndimage.generic_filter(b39, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b39_mean.npy', b39_mean)

# b87= high_res_radiance[86, :, :]
# b87_std = ndimage.generic_filter(b87, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b87_std.npy', b87_std)

# b78= high_res_radiance[77, :, :]
# b78_mean = ndimage.generic_filter(b78, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b78_mean.npy', b78_mean)

# b92= high_res_radiance[91, :, :]
# b92_mean = ndimage.generic_filter(b92, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b92_mean.npy', b92_mean)

# b95= high_res_radiance[94, :, :]
# b95_mean = ndimage.generic_filter(b95, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b95_mean.npy', b95_mean)

# b72 = high_res_radiance[71, :, :]
# b72_mean = ndimage.generic_filter(b72, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b72_mean.npy', b72_mean)

# b74= high_res_radiance[73, :, :]
# b74_std = ndimage.generic_filter(b74, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b74_std.npy', b74_std)

# b80= high_res_radiance[79, :, :]
# b80_std = ndimage.generic_filter(b80, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b80_std.npy', b80_std)

# b18 = high_res_radiance[17, :, :]
# b18_mean = ndimage.generic_filter(b18, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b18_mean.npy', b18_mean)

# %%
# b74 = high_res_radiance[73, :, :]
# b74_mean = ndimage.generic_filter(b74, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b74_mean.npy', b74_mean)

# b58 = high_res_radiance[57, :, :]
# b58_mean = ndimage.generic_filter(b58, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b58_mean.npy', b58_mean)


# b29 = high_res_radiance[28, :, :]
# b29_mean = ndimage.generic_filter(b29, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b29_mean.npy', b29_mean)

# b86 = high_res_radiance[85, :, :]
# b86_mean = ndimage.generic_filter(b86, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b86_mean.npy', b86_mean)

# b88 = high_res_radiance[87, :, :]
# b88_mean = ndimage.generic_filter(b88, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b88_mean.npy', b88_mean)


# b36 = high_res_radiance[35, :, :]
# b36_mean = ndimage.generic_filter(b36, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b36_mean.npy', b36_mean)


# b90= high_res_radiance[89, :, :]
# b90_std = ndimage.generic_filter(b90, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b90_std.npy', b90_std)


# b73= high_res_radiance[72, :, :]
# b73_std = ndimage.generic_filter(b73, np.nanstd, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b73_std.npy', b73_std)

b97 = high_res_radiance[96, :, :]
b97_mean = ndimage.generic_filter(b97, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b97_mean.npy', b97_mean)


# b80 = high_res_radiance[79, :, :]
# b80_mean = ndimage.generic_filter(b80, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b80_mean.npy', b80_mean)



# b76 = high_res_radiance[75, :, :]
# b76_mean = ndimage.generic_filter(b76, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b76_mean.npy', b76_mean)



# b82 = high_res_radiance[81, :, :]
# b82_mean = ndimage.generic_filter(b82, np.nanmean, size=19, mode='constant', cval=np.NaN)
# np.save('E:/wenqu/numpy_file/npy_file/site1b/b82_mean.npy', b82_mean)

# %%
b94= high_res_radiance[93, :, :]
b94_std = ndimage.generic_filter(b94, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b94_std.npy', b94_std)

# %%
# b77_std
b77= high_res_radiance[76, :, :]
b77_std = ndimage.generic_filter(b77, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b77_std.npy', b77_std)
# b34_mean
b34= high_res_radiance[33, :, :]
b34_mean = ndimage.generic_filter(b34, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b34_mean.npy', b34_mean)
# b55_std
b55= high_res_radiance[54, :, :]
b55_std = ndimage.generic_filter(b55, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b55_std.npy', b55_std)

# %%
# b37_mean
b37= high_res_radiance[36, :, :]
b37_mean = ndimage.generic_filter(b37, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b37_mean.npy', b37_mean)

# %%
b32= high_res_radiance[31, :, :]
b32_mean = ndimage.generic_filter(b32, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b32_mean.npy', b32_mean)


b51 = high_res_radiance[50, :, :]
b51_mean = ndimage.generic_filter(b51, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b51_mean.npy', b51_mean)

# %%
b87 = high_res_radiance[86, :, :]
b87_mean = ndimage.generic_filter(b87, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b87_mean.npy', b87_mean)

b42 = high_res_radiance[41, :, :]
b42_mean = ndimage.generic_filter(b42, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b42_mean.npy', b42_mean)

b38 = high_res_radiance[37, :, :]
b38_mean = ndimage.generic_filter(b38, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b38_mean.npy', b38_mean)


b119 = high_res_radiance[118, :, :]
b119_mean = ndimage.generic_filter(b119, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b119_mean.npy', b119_mean)


b76= high_res_radiance[75, :, :]
b76_std = ndimage.generic_filter(b76, np.nanstd, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b76_std.npy', b76_std)

b64 = high_res_radiance[63, :, :]
b64_mean = ndimage.generic_filter(b64, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b64_mean.npy', b64_mean)

# %%
b116 = high_res_radiance[115, :, :]
b116_mean = ndimage.generic_filter(b116, np.nanmean, size=19, mode='constant', cval=np.NaN)
np.save('E:/wenqu/numpy_file/npy_file/site1b/b116_mean.npy', b116_mean)
